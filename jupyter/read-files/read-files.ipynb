# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'read-files.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3 = pandas.read_excel("supermarkets.xlsx")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df6
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7.set_index?

# %%
df7.loc[0:2, "Address":"Employees"]
# Out:
#           Address           City Country  Employees
# 0    3666 21st St  San Francisco     USA          8
# 1  735 Dolores St  San Francisco     USA         15
# 2     332 Hill St  San Francisco     USA         25

# %%
df7.iloc[0:3, 0:4]
# Out:
#           Address           City Country  Employees
# 0    3666 21st St  San Francisco     USA          8
# 1  735 Dolores St  San Francisco     USA         15
# 2     332 Hill St  San Francisco     USA         25

# %%
df7.ix[3, "Name"]
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# "Ben's Shop"

# %%
df7.iloc[3, 4]
# Out:
# 4

# %%
df7.drop("City",1)
# Out:
#            Address Country  Employees  ID         Name             State
# 0     3666 21st St     USA          8   1      Madeira          CA 94114
# 1   735 Dolores St     USA         15   2  Bready Shop          CA 94119
# 2      332 Hill St     USA         25   3  Super River  California 94114
# 3     3995 23rd St     USA         10   4   Ben's Shop          CA 94114
# 4  1056 Sanchez St     USA         12   5      Sanchez        California
# 5  551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
type(df7)
# Out:
# pandas.core.frame.DataFrame

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeFarm',
#  'GeocoderDotUS',
#  'GoogleV3',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'NaviData',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Photon',
#  'Point',
#  'What3Words',
#  'YahooPlaceFinder',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
result = geolocator.geocode('Avenida Paulista, Cerqueira Cesar Sao Paulo')
print(result.raw)
# Out:
# {'place_id': '115389623', 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright', 'osm_type': 'way', 'osm_id': '196799733', 'boundingbox': ['-23.5581761', '-23.5575555', '-46.660946', '-46.6602466'], 'lat': '-23.5578826', 'lon': '-46.6605774', 'display_name': 'Avenida Paulista, Cerqueira César, Jardim Paulista, SP, Microrregião de São Paulo, RMSP, Mesorregião Metropolitana de São Paulo, SP, Região Sudeste, 01311-300, Brasil', 'class': 'highway', 'type': 'primary', 'importance': 0.5}

# %%
df7
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df7["Address"]=df7["Address"] + "," + df7["City"] + "," + df7["State"] + "," + df7["Country"]
df7
# Out:
#                                           Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114,USA  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119,USA  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,USA  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114,USA  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California,USA  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco     USA
#
#    Employees  ID         Name             State
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114

# %%
df7["Coordinates"] = df7["Address"].apply(geolocator.geocode)
df7.Coordinates
# Out:
# 0    (21st Street, Castro District, SF, California,...
# 1                                                 None
# 2    (Hill Street, Liberty Street Historic District...
# 3    (3995, 23rd Street, Noe Valley, SF, California...
# 4    (Sanchez Street, Noe Valley, SF, California, 9...
# 5    (Alvarado Street, Noe Valley, SF, California, ...
# Name: Coordinates, dtype: object

# %%
df7.Coordinates[0].latitude
type(df7.Coordinates[0])
# Out:
# geopy.location.Location

# %%
df7["Latitude"] = df7.Coordinates.apply(lambda x: x.latitude if x != None else None)
df7
# Out:
#                                           Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114,USA  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119,USA  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,USA  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114,USA  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California,USA  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates   Latitude
# ...

# %%
df7["Longitude"] = df7.Coordinates.apply(lambda x: x.longitude if x != None else None)
df7
# Out:
#                                           Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114,USA  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119,USA  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,USA  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114,USA  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California,USA  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114,USA  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          Coordinates   Latitude   Longitude
# ...
